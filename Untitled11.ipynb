# %% [markdown]
# <a href="https://colab.research.google.com/github/s4bih/image/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.utils import shuffle
from skimage import io

# %%
def closest_color(rgb_color):
  color_names = {
      'Red': (255, 0, 0),
      'Green': (0, 255, 0),
      'Blue': (0, 0, 25),
      'Yellow': (255, 255, 0),
      'Purple': (128, 0, 128),
      'Orange': (255, 165, 0),
      'Pink': (255, 192, 203),
      'Brown': (165, 42, 42),
      'Black': (0, 0, 0),
      'White': (255, 255, 255)
  }

  min_distance = float('inf')
  closest_name = None

  for name, color in color_names.items():
      distance = np.linalg.norm(np.array(rgb_color) - np.array(color))
      if distance < min_distance:
          min_distance = distance
          closest_name = name

  return closest_name

# %%
image  = np.array(image, dtype=np.float64) / 255
w, h, d = original_shape = tuple(image.shape)
assert d == 3
image_array = np.reshape(image, (w * h, d))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-fcc023d926cd> in <cell line: 0>()
# ----> 1 image  = np.array(image, dtype=np.float64) / 255
#       2 w, h, d = original_shape = tuple(image.shape)
#       3 assert d == 3
#       4 image_array = np.reshape(image, (w * h, d))
#
# NameError: name 'image' is not defined

# %%
n_color = 5
k_means = KMeans(n_clusters=n_color, random_state=42).fit(image_array)
labels = k_means.predict(image_array)
dominant_color = k_means.cluster_centers_
labels = labels.reshape(original_shape[:2])color_name = [closest_color(color) for color in dominant_color]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4b467f0854e3> in <cell line: 0>()
#       1 n_color = 5
# ----> 2 k_means = KMeans(n_clusters=n_color, random_state=42).fit(image_array)
#       3 labels = k_means.predict(image_array)
#       4 dominant_color = k_means.cluster_centers_
#       5 labels = labels.reshape(original_shape[:2])
#
# NameError: name 'image_array' is not defined
