# %% [markdown]
# <a href="https://colab.research.google.com/github/s4bih/image/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam

from sklearn.metrics import mean_absolute_error, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
import pandas as pd
import re
import gdown

google_drive_link = 'https://drive.google.com/file/d/1wfpbNWY4S39u5GuNxBr218N_gyXmCEUv/view?usp=drive_link'
file_id = re.search(r'file/d/(\w+)', google_drive_link).group(1)

output_file = ('GenderPrediction.csv')
gdown.download(f'https://drive.google.com/uc?id={file_id}', output_file, quiet = False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1wfpbNWY4S39u5GuNxBr218N_gyXmCEUv
# From (redirected): https://drive.google.com/uc?id=1wfpbNWY4S39u5GuNxBr218N_gyXmCEUv&confirm=t&uuid=e2d63721-b34d-4cd3-946d-24ebffc6f928
# To: /content/GenderPrediction.csv
# 100%|██████████| 200M/200M [00:01<00:00, 148MB/s]
# 'GenderPrediction.csv'

# %%
data = pd.read_csv(output_file)
data
# Out:
#        age  ethnicity  gender                        img_name  \
# 0        1          2       0  20161219203650636.jpg.chip.jpg
# 1        1          2       0  20161219222752047.jpg.chip.jpg
# 2        1          2       0  20161219222832191.jpg.chip.jpg
# 3        1          2       0  20161220144911423.jpg.chip.jpg
# 4        1          2       0  20161220144914327.jpg.chip.jpg
# ...    ...        ...     ...                             ...
# 23700   99          0       1  20170120221920654.jpg.chip.jpg
# 23701   99          1       1  20170120134639935.jpg.chip.jpg
# 23702   99          2       1  20170110182418864.jpg.chip.jpg
# 23703   99          2       1  20170117195405372.jpg.chip.jpg
# 23704   99          0       1  20170110182052119.jpg.chip.jpg
#
#                                                   pixels
# 0      129 128 128 126 127 130 133 135 139 142 145 14...
# 1      164 74 111 168 169 171 175 182 184 188 193 199...
# 2      67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3      193 197 198 200 199 200 202 203 204 205 208 21...
# 4      202 205 209 210 209 209 210 211 212 214 218 21...
# ...                                                  ...
# 23700  127 100 94 81 77 77 74 99 102 98 128 145 160 1...
# 23701  23 28 32 35 42 47 68 85 98 103 113 117 130 129...
# 23702  59 50 37 40 34 19 30 101 156 170 177 184 187 1...
# 23703  45 108 120 156 206 197 140 180 191 199 204 207...
# 23704  156 161 160 165 170 173 166 177 183 191 187 18...
#
# [23705 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23705 entries, 0 to 23704
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        23705 non-null  int64
#  1   ethnicity  23705 non-null  int64
#  2   gender     23705 non-null  int64
#  3   img_name   23705 non-null  object
#  4   pixels     23705 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 926.1+ KB

# %%
data['gender'].value_counts()
# Out:
# gender
# 0    12391
# 1    11314
# Name: count, dtype: int64

# %%
#make bar plot about gender
sns.countplot(x = 'gender', data = data)
plt.xlabel('Gender (0: Female, 1: Male)')

plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Formating Data

# %%
import numpy
data['pixels'] = data['pixels'].map(lambda x: np.array(x.split(), dtype = 'float32').reshape(48,48))
data.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  [[129.0, 128.0, 128.0, 126.0, 127.0, 130.0, 13...
# 1  [[164.0, 74.0, 111.0, 168.0, 169.0, 171.0, 175...
# 2  [[67.0, 70.0, 71.0, 70.0, 69.0, 67.0, 70.0, 79...
# 3  [[193.0, 197.0, 198.0, 200.0, 199.0, 200.0, 20...
# 4  [[202.0, 205.0, 209.0, 210.0, 209.0, 209.0, 21...

# %%
images = np.array(data['pixels'].to_list())

# %%
labels = data['gender'].values

# %%
images_reshape = images.reshape(images.shape[0], 48, 48, 1)

# %%
images
# Out:
# array([[[129., 128., 128., ..., 118.,  99.,  53.],
#         [130., 129., 128., ..., 117.,  98.,  52.],
#         [131., 129., 130., ..., 114.,  97.,  50.],
#         ...,
#         [121., 138., 147., ..., 151., 150., 148.],
#         [117., 137., 146., ..., 149., 148., 148.],
#         [115., 135., 142., ..., 146., 146., 146.]],
#
#        [[164.,  74., 111., ..., 111., 111., 104.],
#         [179.,  70., 128., ..., 112., 113., 108.],
#         [176.,  71., 146., ..., 112., 112., 109.],
#         ...,
#         [192., 196., 235., ..., 111., 124., 112.],
#         [230., 226., 233., ..., 198., 197., 180.],
#         [238., 239., 233., ..., 182., 170., 148.]],
#
#        [[ 67.,  70.,  71., ..., 197., 194., 192.],
#         [ 65.,  66.,  69., ..., 197., 194., 192.],
#         [ 61.,  63.,  69., ..., 197., 194., 190.],
#         ...,
#         [159., 157., 159., ..., 114., 105., 105.],
#         [102., 114., 110., ..., 114., 110., 107.],
#         [ 98.,  97.,  95., ..., 112., 111., 108.]],
#
#        ...,
#
#        [[ 59.,  50.,  37., ..., 119., 113.,  98.],
#         [ 56.,  48.,  44., ..., 111., 115.,  97.],
#         [ 40.,  32.,  26., ..., 108., 117., 101.],
#         ...,
#         [ 35.,  55., 106., ...,  93.,  61.,  65.],
#         [ 41.,  40.,  71., ..., 104.,  66.,  71.],
#         [ 47.,  35.,  45., ...,  98.,  78.,  78.]],
#
#        [[ 45., 108., 120., ...,  31.,  36.,  53.],
#         [ 73.,  94., 140., ...,  29.,  30.,  45.],
#         [ 88., 111., 160., ...,  28.,  12.,  33.],
#         ...,
#         [  6.,   2.,  10., ...,   8.,  14.,  34.],
#         [  2.,   4.,  52., ...,  16.,  51.,  41.],
#         [  1.,  36.,  70., ...,  32.,  35.,  35.]],
#
#        [[156., 161., 160., ..., 149., 143., 146.],
#         [153., 145., 164., ..., 147., 138., 132.],
#         [148., 145., 159., ..., 149., 140., 142.],
#         ...,
#         [204., 219., 222., ..., 189., 184., 172.],
#         [213., 210., 223., ..., 195., 191., 168.],
#         [212., 218., 222., ..., 190., 184., 174.]]], dtype=float32)

# %%
if np.max(images_reshape) > 1:
  images_reshape = images_reshape/255.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(images_reshape, labels, test_size = 0.2, random_state = 42)

# %%
X_train, val_image, y_test, val_label = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42)

# %%
print(len(X_test))
print(len(val_image))
print(len(X_train))
# Out:
# 4741
# 2371
# 2370

# %%
fig, axes = plt.subplots(20, 5, figsize=(15,20))

for row in range(20):
  for col in range(5):
    random_face = np.random.choice(len(data))
    image = data['pixels'][random_face]

    axes[row, col].imshow(image, cmap='gray')
    axes[row, col].axis('off')

plt.show()

# %%
fig, axes = plt.subplots(20, 5, figsize=(30,40))
#random select and display 5 faces with their gender label
for row in range(20):
  for col in range(5):
    random_face = np.random.choice(len(data))
    image = data['pixels'][random_face]
    axes[row, col].imshow(image, cmap='gray')
